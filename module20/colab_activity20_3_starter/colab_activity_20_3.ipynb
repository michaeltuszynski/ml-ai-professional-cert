# %% [markdown]
# ### Colab Activity 20.3: Gradient Boosting
#
# **Expected Time = 60 minutes**
#
#
# This activity focuses on using the Gradient Boosting models in Scikit-Learn.  A dataset similar to the lecture example is created for the regression problem.  For classification, the same fetal health dataset from the earlier parts of the module is used.
#
# #### Index
#
# - [Problem 1](#-Problem-1)
# - [Problem 2](#-Problem-2)
# - [Problem 3](#-Problem-3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay

# %%
def f(x):
    '''
    Small example regression dataset.
    '''
    np.random.seed(42)
    return np.sin(x**2) + np.random.normal(size = len(x), scale = 0.1)

# %%
x = np.linspace(0, 3, 20)
y = f(x)

# %%
X = x.reshape(-1, 1) #Make it 2D for sklearn

# %%
plt.scatter(x, y)

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 1
#
# #### Gradient Boosted Regressor
#
#
# Use the `GradientBoostingRegressor` to create a model with default parameters `reg` and fit the model on `X` and `y`.  Assign the predictions as an array to `reg_pred`.  Uncomment the code to visualize the results.

# %%
reg = GradientBoostingRegressor()
reg.fit(X, y)
reg_pred = reg.predict(X)


### ANSWER CHECK
plt.scatter(x, y, color = 'blue', alpha = 0.2, label = 'data')
plt.plot(x, reg_pred, '--ro', alpha = 0.2, label = 'predictions')
plt.legend();

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 2
#
# #### Gradient Boosting Classifier
#
#
#
# The data for classification is again loaded and prepared below.  Use this to create a `GradientBoostingClassifier` with `random_state=0` named `clf` and fit this on the training data.  Score the accuracy of the model as `boost_acc` below.

# %%
df = pd.read_csv('data/fetal.zip', compression = 'zip')
X = df.drop('fetal_health', axis = 1).values
y = df['fetal_health']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                   random_state=42)

# %%
clf = GradientBoostingClassifier(random_state=0)
clf.fit(X_train, y_train)
boost_acc = clf.score(X_test, y_test)


### ANSWER CHECK
print(boost_acc)
# Out:
# 0.9511278195488722

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 3
#
# #### Evaluating the Model
#
#
#
# Create a confusion matrix for the boosted model on the test data.  Which label was best predicted?  Enter your answer as an integer to `ans3` below -- 1, 2, or 3.

# %%
# Problem 3
y_pred = clf.predict(X_test)
conf_matrix = pd.crosstab(y_test, y_pred)
diag = np.diag(conf_matrix)
ans3 = np.argmax(diag) + 1



### ANSWER CHECK
print(type(ans3))
print(ans3)
# Out:
# <class 'numpy.int64'>
# 1

# %% [markdown]
# ## Notebook Summary: Gradient Boosting Models
#
# This notebook explores gradient boosting implementation using scikit-learn, covering both regression and classification tasks.
#
# ### Exercise Overview
#
# 1. **Regression with Gradient Boosting**
#    - Created synthetic dataset using sine wave pattern with noise
#    - Implemented GradientBoostingRegressor with default parameters
#    - Visualized model predictions against actual data points
#
# 2. **Classification with Gradient Boosting**
#    - Used fetal health dataset for multi-class classification
#    - Implemented GradientBoostingClassifier
#    - Evaluated model accuracy on test data
#
# 3. **Model Evaluation**
#    - Created confusion matrix to analyze predictions
#    - Identified best-predicted class
#    - Demonstrated practical model assessment techniques
#
# ### Key Takeaways
#
# - Gradient boosting is versatile, handling both regression and classification tasks
# - Model evaluation differs between regression (visualization) and classification (confusion matrix)
# - Real-world data (fetal health) requires different approaches than synthetic data
# - Confusion matrices help identify which classes are predicted more accurately
# - Default parameters in gradient boosting can provide good baseline performance
#
# This activity demonstrates the practical implementation of gradient boosting models and various techniques for evaluating their performance.
