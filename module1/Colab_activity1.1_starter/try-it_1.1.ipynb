# %% [markdown]
# # Self-Study Colab Activity 1.1: Creating Hist, Scatter, Line, and Bar Plots

# %% [markdown]
# ### In this exercise, generate some basic charts using Pandas.

# %%
# import data from pandas
import pandas as pd
import os

#Make directory called plots
os.makedirs("plots", exist_ok=True)

#create the DataFrame utilizing Pandas
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
#save the data to a csv file
data.to_csv('nba.csv', index=False)

#generate all info for this dataset
data.info()

#Remove the last line of NAN
data = data.iloc[:-1 , :]

#Ignore any warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# ###  Part One: In this exercise, generate a basic histogram.

# %%
#Please generate a basic histogram and save the histogram as a png file
# Hint: use pandas histogram function.
hist = data['Salary'].plot.hist(title='NBA Salaries Distribution')
hist.figure.savefig('plots/salary_histogram.png')

# %% [markdown]
# ###  Part Two: In this exercise, generate a basic scatter plot.

# %%
#Please generate a basic scatter plot utilizing Age as the x axis and Salary as the y axis
# Hint: use pandas scatter function to generate the chart.

scat = data.plot.scatter(x='Age', y='Salary',
                        title='NBA Player Age vs Salary')
scat.figure.savefig('plots/age_salary_scatter.png')


print(scat)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ###  Part Three: In this exercise, generate a basic lineplot.

# %%
# Please generate a basic line plot by name as the x axis and salary as the y axis
#for the "Golden State Warriors" using the nba data set.
#Note a new dataframe called teamdata has been created for you that will be used during the rest of this



teamdata = data.filter(items=['Team', 'Name', 'Salary'])
teamdata = teamdata.loc[data.Team == 'Golden State Warriors', 'Name':'Salary']
teamdata.set_index('Name')


lines = teamdata.plot.line(x='Name', y='Salary',
                          title='Golden State Warriors Player Salaries')
lines.figure.savefig('plots/gsw_salary_line.png')



# ANSWER CHECK
print(lines)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ###  Part Four: In this exercise, generate a basic bar chart.

# %%
# Please generate a basic bar plot by name as the x axis and salary as the y axis of the teamdata dataframe.


bar = teamdata.plot.bar(x='Name', y='Salary',
                       title='Golden State Warriors Player Salaries')
bar.figure.savefig('plots/gsw_salary_bar.png')



print(bar)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# # Summary of Data Visualization Exercises
#
# This notebook demonstrates fundamental data visualization techniques using Pandas and its built-in plotting capabilities.
#
# ## Exercises Overview
# 1. **Histogram**: Visualized the distribution of NBA player salaries
# 2. **Scatter Plot**: Explored the relationship between player age and salary
# 3. **Line Plot**: Displayed salary trends for Golden State Warriors players
# 4. **Bar Chart**: Compared individual player salaries for Golden State Warriors
#
# ## Key Takeaways
# - Pandas provides convenient plotting functions through `.plot` accessor
# - Different plot types serve different analytical purposes:
#   - Histograms for distribution analysis
#   - Scatter plots for relationship exploration
#   - Line plots for trend visualization
#   - Bar charts for comparison between categories
# - Plots can be easily saved using `.savefig()` method
# - Data filtering and preparation is crucial for meaningful visualizations
# - Proper titles and labels enhance plot interpretability
#
# ## Technical Notes
# - Used pandas' built-in plotting functions (wrappers around matplotlib)
# - Implemented file saving functionality with organized directory structure
# - Demonstrated data filtering and DataFrame manipulation for specific team analysis
