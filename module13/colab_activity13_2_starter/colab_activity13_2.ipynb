# %% [markdown]
# ### Colab activity 13.2: Decision Boundaries with Two Variable
#
# **Expected Time = 60 minutes**
#
#
# In the first examples, your work has utilized a straight vertical line as the decision boundary for logistic regression. This is what a decision boundary looks like with only one feature, however with two features the decision boundary becomes a linear function of the two inputs. In this activity, you will focus on generating functions for these boundaries and show strategies for visualizing these boundaries.
#
# #### Index
#
#   - [Problem 1](#-Problem-1)
#   - [Problem 2](#-Problem-2)
#   - [Problem 3](#-Problem-3)
#   - [Problem 4](#-Problem-4)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### The Data
#
# Again, you will use the penguins data from Seaborn.  This time, you will use two features -- `flipper_length_mm` and `bill_length_mm` to build a logistic model and visualize the decision boundary.  The data is loaded and visualized below.

# %%
penguins = sns.load_dataset('penguins').dropna()
penguins = penguins.loc[(penguins['species'] == 'Adelie') | (penguins['species'] == 'Gentoo')]
X = penguins.drop('species', axis = 1)[['flipper_length_mm', 'bill_length_mm']]
y = np.where(penguins.species == 'Adelie', 0, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
X.head()
# Out:
#    flipper_length_mm  bill_length_mm
# 0              181.0            39.1
# 1              186.0            39.5
# 2              195.0            40.3
# 4              193.0            36.7
# 5              190.0            39.3

# %%
sns.scatterplot(data = penguins, x = 'flipper_length_mm', y = 'bill_length_mm', hue = 'species')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 1
#
# #### A Logistic Model
#
#
# Instantiate a `LogisticRegression` estimator as `log_reg` below and fit on the training data `X_train` and `y_train`.

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)



# Answer check
print(log_reg)
# Out:
# LogisticRegression()

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 2
#
# #### Examining the coefficients
#
#
# With two variables, the Sigma function is given by:
#
# $$\sigma(x) = \frac{1}{1 + e^{-z}},$$
#
# where
#
# $$z = \beta_0 + \beta_1 * x_0 + \beta_2 * x_1.$$
#
# Below, assign the intercept to  `beta_0` and the  coefficients to `beta_1` and `beta_2`, respectively.
#
# Note that $x_0$ is the flipper length.

# %%
beta_0 = ''
beta_1 = ''
beta_2 = ''

# Extract coefficients and intercept
beta_0 = log_reg.intercept_[0]  # intercept
beta_1 = log_reg.coef_[0][0]    # coefficient for flipper_length_mm
beta_2 = log_reg.coef_[0][1]    # coefficient for bill_length_mm

# Print for verification
print(f"beta_0 (intercept): {beta_0:.4f}")
print(f"beta_1 (flipper_length): {beta_1:.4f}")
print(f"beta_2 (bill_length): {beta_2:.4f}")

# Answer check
print(f'z = {beta_0: .2f} + {beta_1: .2f}x0 + {beta_2: .2f}x1')
# Out:
# beta_0 (intercept): -156.0728
# beta_1 (flipper_length): 0.6129
# beta_2 (bill_length): 0.6902
# z = -156.07 +  0.61x0 +  0.69x1

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 3
#
# #### Visualizing the decision boundary
#
#
# <center>
#     <img src = 'images/dboundary.png' />
# </center>
#
#
# There is both a brute force and more formal approach for visualizing the decision boundary.
#
# With two variables we can directly solve for the linear function in terms of `x_0` and  `beta`'s. Upon doing so we find a linear function defined as:
#
# $$y = -\frac{\beta_1}{\beta_2} * x_0 - \frac{\beta_0}{\beta_2}$$
#
# Complete the function `decision_boundary` below that takes in `x_0` and  `beta`'s. This function should return the appropriate value for the predicitons based on the formula above.  Uncomment the plot to verify your results using the defined `x = np.linspace`.

# %%
def decision_boundary(x0, beta_0, beta_1, beta_2):
    '''
    Function returns values for linear decision boundaries
    in binary classification setting according to the formula
    y = -beta_1/beta_2 * x0 - beta_0/beta_2

    Arguments
    ---------
    x0: np.array
        domain for evaluation of function

    beta_0: float
         intercept from fit logistic model
    beta_1: float
        first coefficient from logistic model
    beta_2: float
        second coefficient from logistic model

    Returns
    -------
    np.array
        values of y
    '''
    return None

def decision_boundary(x0, beta_0, beta_1, beta_2):
    '''
    Function returns values for linear decision boundaries
    in binary classification setting according to the formula
    y = -beta_1/beta_2 * x0 - beta_0/beta_2
    '''
    # Calculate the decision boundary values
    y = -(beta_1/beta_2) * x0 - (beta_0/beta_2)
    return y

# Test the function
x = np.linspace(165, 240, 100)
y = decision_boundary(x, beta_0, beta_1, beta_2)

# Uncomment to visualize
sns.scatterplot(data=penguins, x='flipper_length_mm', y='bill_length_mm', hue='species')
plt.plot(x, y, '--', color='black')
plt.ylim(25, 65)
plt.fill_between(x, y, alpha=0.3, color='lightblue')
plt.fill_between(x, y, np.repeat(70, 100), alpha=0.3)

# Answer check
x = np.linspace(165, 240, 100)
print(decision_boundary(x, beta_0, beta_1, beta_2)[0], decision_boundary(x, beta_0, beta_1, beta_2)[-1])
# Out:
# 79.61672431323615 13.018550498400117

# %%
## code for figure
#x = np.linspace(165, 240, 100)
#sns.scatterplot(data = penguins, x = 'flipper_length_mm', y = 'bill_length_mm', hue = 'species')
#plt.plot(x, decision_boundary(x, beta_0, beta_1, beta_2), '--', color = 'black')
#plt.ylim(25, 65)
#plt.fill_between(x, decision_boundary(x, beta_0, beta_1, beta_2), alpha = 0.3, color = 'lightblue')
#plt.fill_between(x, decision_boundary(x, beta_0, beta_1, beta_2), np.repeat(70, 100), alpha = 0.3)

# %% [markdown]
# [Back to top](#-Index)
#
# ### Problem 4
#
# #### Comparing regressors
#
#
# Now, fit a second regressor using the argument `C = 0.001`. Compare the decision boundary by using what you've seen earlier. How did the decision boundary change based on this?  The slope of the new decision boundary should either be greater than or less than the default settings. Assign your answer as a string -- `greater than` or `less than` -- to `ans4` below. Hint: Remember that the slope is negative.

# %%
ans4 = ''

# Fit new model with stronger regularization
log_reg_reg = LogisticRegression(C=0.001)
log_reg_reg.fit(X_train, y_train)

# Get new coefficients
beta_0_reg = log_reg_reg.intercept_[0]
beta_1_reg = log_reg_reg.coef_[0][0]
beta_2_reg = log_reg_reg.coef_[0][1]

# Calculate slopes for comparison
slope_default = -(beta_1/beta_2)
slope_regularized = -(beta_1_reg/beta_2_reg)

# Compare slopes (remember they're negative)
ans4 = 'greater than' if abs(slope_regularized) < abs(slope_default) else 'less than'

# Visualize to verify
x = np.linspace(165, 240, 100)
plt.figure(figsize=(10, 6))
sns.scatterplot(data=penguins, x='flipper_length_mm', y='bill_length_mm', hue='species')
plt.plot(x, decision_boundary(x, beta_0, beta_1, beta_2), '--', color='black', label='Default')
plt.plot(x, decision_boundary(x, beta_0_reg, beta_1_reg, beta_2_reg), '--', color='red', label='C=0.001')
plt.legend()
plt.ylim(25, 65)

# Answer check
print(ans4)
# Out:
# less than

# %% [markdown]
# ### Summary of Exercises
#
# This notebook explores logistic regression with two features using penguin data, focusing on decision boundaries and their visualization.
#
# **Problem 1:** Implemented basic logistic regression model using flipper length and bill length to classify penguin species (Adelie vs Gentoo).
#
# **Problem 2:** Examined the logistic regression coefficients (β₀, β₁, β₂) to understand the model's parameters in the context of the sigmoid function:
# σ(x) = 1/(1 + e^(-z)), where z = β₀ + β₁x₀ + β₂x₁
#
# **Problem 3:** Visualized the decision boundary using the formula:
# y = -(β₁/β₂)x₀ - (β₀/β₂)
# Created a plot showing the linear decision boundary separating the two penguin species.
#
# **Problem 4:** Explored the impact of regularization (C=0.001) on the decision boundary slope, demonstrating how stronger regularization affects the model's decision surface.
#
# ### Key Takeaways
#
# 1. With two features, logistic regression creates a linear decision boundary in 2D space
# 2. The decision boundary can be derived mathematically from the model coefficients
# 3. Regularization strength (C parameter) affects the slope of the decision boundary
# 4. Visualization techniques like scatter plots with overlaid decision boundaries help understand model behavior
# 5. The relationship between model parameters (β values) directly determines the orientation and position of the decision boundary
