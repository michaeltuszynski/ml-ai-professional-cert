# %% [markdown]
# ### Required Codio Assignment 3.1: Replicating Data Visualizations
#
# **Expected Time: 30 Minutes**
#
# **Total Points: 10**
#
# This activity focuses on duplicating a given plot using the appropriate plotting library.  The `gapminder` dataset from plotly is used.  For each Problem, you will be shown an image of a plot produced using `matplotlib`, and `seaborn`.  You are asked to replicate the plot and enter the appropriate code for each Problem.
#
# ## Index:
#
# - [Problem 1](#Problem-1)
# - [Problem 2](#Problem-2)
# - [Problem 3](#Problem-3)
# - [Problem 4](#Problem-4)

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gapminder = px.data.gapminder()

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gapminder.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 1
#
# **Basic Histogram**
#
# **2 Points**
#
# Use the `pandas` method `hist` to create a histogram plot of the column `lifeExp`.
#
# Set the title of your plot equal to `Histogram of Life Expentancy`.
#
#
# Save your plot as a png file with the name `plot1.png` in the folder `images`.
#
#
# ![](images/np1.png)

# %%
### GRADED

# YOUR CODE HERE
gapminder['lifeExp'].hist()
plt.title('Histogram of Life Expentancy')
plt.savefig('images/plot1.png')

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 2
#
# **Boxplots**
#
# **3 Points**
#
# Use `Seaborn` to create a boxplot of the `gapminder` dataframe. Sr the argument `x` equal to `lifeExp` and the variable `y` equal to `continent`.
#
# Save your plot as a png file with the name `plot2.png` in the folder `images`.
#
# ![](images/np2.png)

# %%
### GRADED

# YOUR CODE HERE
sns.boxplot(x='lifeExp', y='continent', data=gapminder)
plt.savefig('images/plot2.png')

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 3
#
# **3 Points**
#
# **Bar Plot**
#
# Use `Seaborn` to create a barplot of the `gapminder` dataframe. Sr the argument `x` equal to `gdpPercap` and the variable `y` equal to `continent`.
#
# Save your plot as a png file with the name `plot3.png` in the folder `images`.
#
# ![](images/p4.png)

# %%
### GRADED

# YOUR CODE HERE
sns.barplot(x='gdpPercap', y='continent', data=gapminder)
plt.savefig('images/plot3.png')

# %% [markdown]
# [Back to top](#Index:)
#
# ### Problem 4
#
# **2 Points**
#
# **Scatterplot**
#
# Use `Seaborn` to create a scatterplot of the `gapminder` dataframe. Sr the argument `x` equal to `gdpPercap` and the variable `y` equal to `lifeExp`.
#
# Save your plot as a png file with the name `plot4.png` in the folder `images`.
#
# ![](images/np4.png)

# %%
### GRADED

# YOUR CODE HERE
sns.scatterplot(x='gdpPercap', y='lifeExp', data=gapminder)
plt.savefig('images/plot4.png')

# %% [markdown]
# # Notebook Summary: Data Visualization with Gapminder Dataset
#
# ## Overview
# This assignment focused on replicating various data visualizations using the Gapminder dataset, demonstrating proficiency with different plotting libraries (Pandas, Matplotlib, and Seaborn).
#
# ## Exercises
# 1. **Basic Histogram (Problem 1)**
#    - Created histogram of life expectancy distribution
#    - Used Pandas' built-in hist() method
#    - Demonstrated basic plot customization with titles
#
# 2. **Boxplot Analysis (Problem 2)**
#    - Created boxplots comparing life expectancy across continents
#    - Used Seaborn's boxplot functionality
#    - Showed distribution and outliers by continent
#
# 3. **Bar Plot (Problem 3)**
#    - Visualized GDP per capita across continents
#    - Used Seaborn's barplot for statistical aggregation
#    - Demonstrated categorical data visualization
#
# 4. **Scatter Plot (Problem 4)**
#    - Created scatter plot of GDP per capita vs life expectancy
#    - Used Seaborn's scatterplot function
#    - Showed relationship between economic and health indicators
#
# ## Key Takeaways
# - Different plot types serve different analytical purposes
# - Seaborn provides high-level interface for statistical visualizations
# - Data visualization requires choosing appropriate plot types for the data and analysis goal
# - The Gapminder dataset provides rich opportunities for exploring global development indicators
